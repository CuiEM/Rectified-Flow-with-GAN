# %% [markdown]
# # choss 25 images from fid/CIFAR10/Fake and plt into 5*5 grid

# %%
import os
import random
import matplotlib.pyplot as plt
from PIL import Image

# %%
# 设置图片目录
# image_dir = '../pretrain/rectified-flow/results'
image_dir = '../eval/fid/CIFAR10/fake'

# 获取目录中所有图片文件
image_files = [f for f in os.listdir(image_dir) if f.endswith(('.png', '.jpg', '.jpeg'))]

# 随机选择25张图片
selected_images = random.sample(image_files, 25)

# 创建5x5的子图
fig, axes = plt.subplots(5, 5, figsize=(5, 5))

# 遍历选中的图片并显示
for i, img_file in enumerate(selected_images):
    img_path = os.path.join(image_dir, img_file)
    img = Image.open(img_path)
    
    row = i // 5
    col = i % 5
    
    axes[row, col].imshow(img)
    axes[row, col].axis('off')

# 调整子图之间的间距
plt.tight_layout()

# 显示图像网格
plt.show()

# %%
# 设置图片目录
# image_dir = '../pretrain/rectified-flow/results'
image_dir = '../eval/fid/CELEBA/fake'

# 获取目录中所有图片文件
image_files = [f for f in os.listdir(image_dir) if f.endswith(('.png', '.jpg', '.jpeg'))]

# 随机选择25张图片
selected_images = random.sample(image_files, 25)

# 创建5x5的子图
fig, axes = plt.subplots(5, 5, figsize=(5, 5))

# 遍历选中的图片并显示
for i, img_file in enumerate(selected_images):
    img_path = os.path.join(image_dir, img_file)
    img = Image.open(img_path)
    
    row = i // 5
    col = i % 5
    
    axes[row, col].imshow(img)
    axes[row, col].axis('off')

# 调整子图之间的间距
plt.tight_layout()

# 显示图像网格
plt.show()
